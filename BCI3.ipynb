# %%
# !pip install numpy moabb
# Out:
# Requirement already satisfied: numpy in c:\users\kimso\anaconda3\envs\sol3\lib\site-packages (1.26.4)
# Requirement already satisfied: moabb in c:\users\kimso\anaconda3\envs\sol3\lib\site-packages (1.1.1)
# Requirement already satisfied: PyYAML<7.0,>=6.0 in c:\users\kimso\anaconda3\envs\sol3\lib\site-packages (from moabb) (6.0.2)
# Requirement already satisfied: coverage<8.0.0,>=7.0.1 in c:\users\kimso\anaconda3\envs\sol3\lib\site-packages (from moabb) (7.6.10)
# Requirement already satisfied: edfio<0.5.0,>=0.4.2 in c:\users\kimso\anaconda3\envs\sol3\lib\site-packages (from moabb) (0.4.5)
# Requirement already satisfied: edflib-python<2.0.0,>=1.0.6 in c:\users\kimso\anaconda3\envs\sol3\lib\site-packages (from moabb) (1.0.8)
# Requirement already satisfied: h5py<4.0.0,>=3.10.0 in c:\users\kimso\anaconda3\envs\sol3\lib\site-packages (from moabb) (3.12.1)
# Requirement already satisfied: matplotlib<4.0.0,>=3.6.2 in c:\users\kimso\anaconda3\envs\sol3\lib\site-packages (from moabb) (3.10.0)
# Requirement already satisfied: memory-profiler<0.62.0,>=0.61.0 in c:\users\kimso\anaconda3\envs\sol3\lib\site-packages (from moabb) (0.61.0)
# Requirement already satisfied: mne<2.0.0,>=1.7.0 in c:\users\kimso\anaconda3\envs\sol3\lib\site-packages (from moabb) (1.9.0)
# Requirement already satisfied: mne-bids<0.15,>=0.14 in c:\users\kimso\anaconda3\envs\sol3\lib\site-packages (from moabb) (0.14)
# Requirement already satisfied: pandas<2.0.0,>=1.5.2 in c:\users\kimso\anaconda3\envs\sol3\lib\site-packages (from moabb) (1.5.3)
# Requirement already satisfied: pooch<2.0.0,>=1.6.0 in c:\users\kimso\anaconda3\envs\sol3\lib\site-packages (from moabb) (1.8.2)
# Requirement already satisfied: pyriemann<0.7,>=0.6 in c:\users\kimso\anaconda3\envs\sol3\lib\site-packages (from moabb) (0.6)
# Requirement already satisfied: pytest<8.0.0,>=7.4.0 in c:\users\kimso\anaconda3\envs\sol3\lib\site-packages (from moabb) (7.4.4)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in c:\users\kimso\anaconda3\envs\sol3\lib\site-packages (from moabb) (2.32.3)
# Requirement already satisfied: scikit-learn>=1.4.2 in c:\users\kimso\anaconda3\envs\sol3\lib\site-packages (from moabb) (1.6.1)
# Requirement already satisfied: scipy<2.0.0,>=1.9.3 in c:\users\kimso\anaconda3\envs\sol3\lib\site-packages (from moabb) (1.15.1)
# Requirement already satisfied: seaborn<0.13.0,>=0.12.1 in c:\users\kimso\anaconda3\envs\sol3\lib\site-packages (from moabb) (0.12.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.64.1 in c:\users\kimso\anaconda3\envs\sol3\lib\site-packages (from moabb) (4.67.1)
# Requirement already satisfied: urllib3<2.0.0,>=1.26.15 in c:\users\kimso\anaconda3\envs\sol3\lib\site-packages (from moabb) (1.26.20)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\kimso\anaconda3\envs\sol3\lib\site-packages (from matplotlib<4.0.0,>=3.6.2->moabb) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\kimso\anaconda3\envs\sol3\lib\site-packages (from matplotlib<4.0.0,>=3.6.2->moabb) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\kimso\anaconda3\envs\sol3\lib\site-packages (from matplotlib<4.0.0,>=3.6.2->moabb) (4.55.5)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\kimso\anaconda3\envs\sol3\lib\site-packages (from matplotlib<4.0.0,>=3.6.2->moabb) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\kimso\anaconda3\envs\sol3\lib\site-packages (from matplotlib<4.0.0,>=3.6.2->moabb) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\kimso\anaconda3\envs\sol3\lib\site-packages (from matplotlib<4.0.0,>=3.6.2->moabb) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\kimso\anaconda3\envs\sol3\lib\site-packages (from matplotlib<4.0.0,>=3.6.2->moabb) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\kimso\anaconda3\envs\sol3\lib\site-packages (from matplotlib<4.0.0,>=3.6.2->moabb) (2.9.0.post0)
# Requirement already satisfied: psutil in c:\users\kimso\anaconda3\envs\sol3\lib\site-packages (from memory-profiler<0.62.0,>=0.61.0->moabb) (6.1.1)
# Requirement already satisfied: decorator in c:\users\kimso\anaconda3\envs\sol3\lib\site-packages (from mne<2.0.0,>=1.7.0->moabb) (5.1.1)
# Requirement already satisfied: jinja2 in c:\users\kimso\anaconda3\envs\sol3\lib\site-packages (from mne<2.0.0,>=1.7.0->moabb) (3.1.5)
# Requirement already satisfied: lazy-loader>=0.3 in c:\users\kimso\anaconda3\envs\sol3\lib\site-packages (from mne<2.0.0,>=1.7.0->moabb) (0.4)
# Requirement already satisfied: pytz>=2020.1 in c:\users\kimso\anaconda3\envs\sol3\lib\site-packages (from pandas<2.0.0,>=1.5.2->moabb) (2024.2)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\kimso\anaconda3\envs\sol3\lib\site-packages (from pooch<2.0.0,>=1.6.0->moabb) (4.3.6)
# Requirement already satisfied: joblib in c:\users\kimso\anaconda3\envs\sol3\lib\site-packages (from pyriemann<0.7,>=0.6->moabb) (1.4.2)
# Requirement already satisfied: iniconfig in c:\users\kimso\anaconda3\envs\sol3\lib\site-packages (from pytest<8.0.0,>=7.4.0->moabb) (2.0.0)
# Requirement already satisfied: pluggy<2.0,>=0.12 in c:\users\kimso\anaconda3\envs\sol3\lib\site-packages (from pytest<8.0.0,>=7.4.0->moabb) (1.5.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc8 in c:\users\kimso\anaconda3\envs\sol3\lib\site-packages (from pytest<8.0.0,>=7.4.0->moabb) (1.2.2)
# Requirement already satisfied: tomli>=1.0.0 in c:\users\kimso\anaconda3\envs\sol3\lib\site-packages (from pytest<8.0.0,>=7.4.0->moabb) (2.2.1)
# Requirement already satisfied: colorama in c:\users\kimso\anaconda3\envs\sol3\lib\site-packages (from pytest<8.0.0,>=7.4.0->moabb) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\kimso\anaconda3\envs\sol3\lib\site-packages (from requests<3.0.0,>=2.28.1->moabb) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\kimso\anaconda3\envs\sol3\lib\site-packages (from requests<3.0.0,>=2.28.1->moabb) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kimso\anaconda3\envs\sol3\lib\site-packages (from requests<3.0.0,>=2.28.1->moabb) (2024.12.14)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\kimso\anaconda3\envs\sol3\lib\site-packages (from scikit-learn>=1.4.2->moabb) (3.5.0)
# Requirement already satisfied: six>=1.5 in c:\users\kimso\anaconda3\envs\sol3\lib\site-packages (from python-dateutil>=2.7->matplotlib<4.0.0,>=3.6.2->moabb) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\kimso\anaconda3\envs\sol3\lib\site-packages (from jinja2->mne<2.0.0,>=1.7.0->moabb) (3.0.2)

# %%
import numpy as np
from moabb.datasets import Cho2017
from moabb.paradigms import LeftRightImagery
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
# Load MOABB dataset
dataset = Cho2017()
paradigm = LeftRightImagery(resample=128)

# Get data from the first subject and the first session

X, y, metadata = paradigm.get_data(dataset=dataset, subjects=[6])
# Out:
# Trials demeaned and stacked with zero buffer to create continuous data -- edge effects present
# C:\Users\kimso\anaconda3\envs\sol3\lib\site-packages\moabb\datasets\preprocessing.py:279: UserWarning: warnEpochs <Epochs | 200 events (all good), 0 – 3 s (baseline off), ~150.2 MiB, data loaded,
#  'left_hand': 100
#  'right_hand': 100>
#   warn(f"warnEpochs {epochs}")
# C:\Users\kimso\anaconda3\envs\sol3\lib\site-packages\sklearn\pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(

# %%
X.shape
# Out:
# (200, 64, 384)

# %%
X
# Out:
# array([[[ 2.70546537e+01, -9.35412444e+00, -4.22655518e+01, ...,
#          -9.01562953e+01, -1.14199139e+02, -1.14616607e+02],
#         [-5.08840636e+01, -9.80188984e+01, -6.98427280e+01, ...,
#          -1.24595158e+02, -7.87529371e+01, -5.86493958e+01],
#         [ 3.98764599e+01,  3.17541825e+01, -2.68324628e+01, ...,
#          -9.44399035e+01, -3.22916470e+01, -3.64232077e+01],
#         ...,
#         [-1.52951274e+02, -2.08705137e+02, -1.89695369e+02, ...,
#          -1.50024193e+01,  2.28136309e+01,  5.86248593e+01],
#         [-4.34821479e+01, -1.02499223e+02, -1.23597445e+02, ...,
#          -4.38716873e+00,  2.57581728e+01,  4.94431963e+01],
#         [-5.42915891e+01, -1.02591736e+02, -1.15490550e+02, ...,
#          -1.09150120e+01,  1.24951885e+01,  4.94636514e+01]],
#
#        [[-7.91398385e+01, -1.61210129e+02, -1.76797410e+02, ...,
#          -2.69557437e+01, -9.62012832e+01, -7.30760465e+01],
#         [-7.67414702e+01, -1.94887317e+02, -2.18188880e+02, ...,
#          -9.69166764e+01, -7.58337982e+01,  2.48611534e+01],
#         [-1.93517954e+02, -2.11595982e+02, -1.19770785e+02, ...,
#          -7.83998706e+01, -1.35967414e+02, -9.11670293e+01],
#         ...,
#         [-1.23431243e+02, -1.56154028e+02, -1.28008227e+02, ...,
#          -2.62720540e+01, -1.35470538e+01, -1.57971074e+01],
#         [-6.86841511e+01, -1.25351028e+02, -1.16433833e+02, ...,
#          -6.00461889e+01, -3.92637420e+01, -2.18195688e+00],
#         [-9.46632720e+01, -1.34271098e+02, -9.65964706e+01, ...,
#          -4.23113550e+01, -9.98750138e+00,  1.96505469e+01]],
#
#        [[ 1.82997367e+02,  4.88675587e+01, -4.40158073e+01, ...,
#          -2.84473616e+01, -1.78499114e+00,  4.98020383e+01],
#         [ 1.35874721e+02, -6.61555056e+01, -9.72908371e+01, ...,
#          -2.42511684e+01, -3.79576822e+00,  7.86910156e+01],
#         [ 1.85230979e+02,  6.49153136e+00, -8.52504631e+01, ...,
#           1.15963240e+01,  9.37271028e+00,  3.63778272e+01],
#         ...,
#         [ 9.59880009e+01, -4.82016788e+00, -7.03917654e+01, ...,
#           4.89677296e+01,  2.38004381e+01, -2.31708619e+01],
#         [ 4.13340103e+01, -1.03716714e+01, -3.30377276e+01, ...,
#           5.60414228e+00, -3.24037710e+00, -3.06074628e+01],
#         [ 6.36446100e+01,  3.59241488e+00, -4.34592640e+01, ...,
#        -1.90516056e+01,  3.79461139e+01,  3.06454580e+01, -1.49195229e+02,
#        -6.36220055e+01, -6.37787550e+00, -1.63659824e+02,  3.09586054e+01,
#        -9.39294456e+01,  3.12849375e+02, -6.21194527e+01,  1.45667488e+02,
#         1.13552883e+02, -5.15392097e+01, -1.71765639e+02,  8.80027586e+01,
#        -7.94606427e+01, -1.25189758e+02,  1.53539460e+02,  1.92215472e+01,
#        -1.35968460e+02, -1.24388013e+02, -6.51153284e+01,  2.95133739e+01,
#         7.23935807e+01,  3.53504250e+02, -1.53220908e+02,  7.81741066e+01,
#        -3.35667049e+01, -1.74287846e+02, -3.10706505e+02, -1.49121024e+02,
#        -6.45834000e+01,  3.37978534e+01, -2.00940276e+01,  3.02539532e+01,
#        -3.82303281e+01,  1.78647561e+02, -2.09734737e+02,  2.89943202e+02,
#         7.56095031e+01,  4.47003052e+01, -8.36515012e+01,  2.84619990e+02])

# %%
C3_index = 12
C4_index = 53

# %%
test = X[:, :, :]
print(test.shape)
test2 = X[:,:,0]
print(test2.shape)
test3 = X[:,0,:]
print(test3.shape)
test4 = X[0,:,:]
print(test4.shape)
# Out:
# (200, 64, 384)
# (200, 64)
# (200, 384)
# (64, 384)

# %%
C3_values = X[:, C3_index, :]

# %%
C3_values.shape
# Out:
# (200, 384)

# %%
C4_values = X[:, C4_index, :]

# %%
C3_value_mean.shape
# Out:
# (200,)

# %%
C3_value_mean = C3_values.mean(axis=1)
C4_values_mean = C4_values.mean(axis=1)
C3_value_std = C3_values.std(axis=1)
C4_value_std = C4_values.std(axis=1)
C3_sub_C4 = C3_values - C4_values

# %%
all_input = np.column_stack((
    C3_value_mean, C4_values_mean, C3_value_std, C4_value_std, C3_sub_C4))

# %%
all_input.shape
# Out:
# (200, 388)

# %%
X_train, X_test, y_train, y_test = train_test_split(all_input, y , test_size = 0.3, random_state = 42)

# %%
clf = LogisticRegression()

# %%
clf.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
predict = clf.predict(X_test)

# %%
predict
# Out:
# array(['right_hand', 'right_hand', 'right_hand', 'right_hand',
#        'right_hand', 'left_hand', 'right_hand', 'left_hand', 'left_hand',
#        'right_hand', 'left_hand', 'right_hand', 'right_hand',
#        'right_hand', 'right_hand', 'right_hand', 'left_hand',
#        'right_hand', 'left_hand', 'right_hand', 'left_hand', 'right_hand',
#        'right_hand', 'left_hand', 'right_hand', 'right_hand',
#        'right_hand', 'left_hand', 'left_hand', 'right_hand', 'right_hand',
#        'right_hand', 'right_hand', 'right_hand', 'right_hand',
#        'right_hand', 'left_hand', 'left_hand', 'right_hand', 'right_hand',
#        'right_hand', 'right_hand', 'left_hand', 'left_hand', 'left_hand',
#        'left_hand', 'left_hand', 'right_hand', 'left_hand', 'left_hand',
#        'left_hand', 'left_hand', 'right_hand', 'left_hand', 'left_hand',
#        'left_hand', 'right_hand', 'right_hand', 'left_hand', 'left_hand'],
#       dtype='<U10')

# %%
accuracy = accuracy_score(y_test, predict)
print(f"정확도 (Accuracy): {accuracy:.2f}")
# Out:
# 정확도 (Accuracy): 0.42
